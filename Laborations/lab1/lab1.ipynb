# %% [markdown]
# <!-- -*- mode: markdown; coding: utf-8; fill-column: 60; ispell-dictionary: "english" -*- -->
#
# <meta charset="utf-8"/>
# <meta name="viewport" content="width=device-width,initial-scale=1"/>
# <link rel="stylesheet" href="style.css">
#
#
# # EDAF75 - lab 1: SQL
#
# **Objective:** to practice writing SQL queries.
#
# This lab is meant to be run as a `jupyter` notebook, you can
# download it [here](lab1.zip) (the zip-file contains the
# notebook and the database, and a [.html-file](lab1.html)
# which you can read in case you have problems reading/running
# jupyter notebooks).
#
# ## Background
#
# We have a database to handles the academic achievements of
# students at LTH -- in it we have three tables:
#
# <hr>
# <table rules="all">
#  <tr>
#   <th align="left"><code>students:</code></th>
#   <th></th>
#  </tr>
#  <tr>
#   <td><code>ssn</code></td>
#   <td>social security number</td>
#  </tr>
#  <tr>
#   <td><code>first_name</code></td>
#   <td>first name (obviously!)</td>
#  </tr>
#  <tr>
#   <td><code>last_name</code></td>
#   <td>last name</td>
#  </tr>
# </table>
#
# <hr>
#
# <table rules="all">
#  <tr>
#   <th align="left"><code>courses:</code></th>
#   <th></th>
#  </tr>
#  <tr>
#   <td><code>course_code</code></td>
#   <td>course code, like <code>EDAF75</code></td>
#  </tr>
#  <tr>
#   <td><code>course_name</code></td>
#   <td>the name of the course, like "Database Technology"</td>
#  </tr>
#  <tr>
#   <td><code>level</code></td>
#   <td>the course level, like "G1", "G2", or "A"</td>
#  </tr>
#  <tr>
#   <td><code>credits</code></td>
#   <td>the number of credits for the course, like 7.5</td>
#  </tr>
# </table>
#
# <hr>
#
# <table rules="all">
#  <tr>
#   <th align="left"><code>taken_courses:</code></th>
#   <th></th>
#  </tr>
#  <tr>
#   <td><code>ssn</code></td>
#   <td>the social security number of a student</td>
#  </tr>
#  <tr>
#   <td><code>course_code</code></td>
#   <td>the course code for the course the student has taken</td>
#  </tr>
#  <tr>
#   <td><code>grade</code></td>
#   <td>the grade for the student passing the course</td>
#  </tr>
# </table>
#
# <hr>
#
# <center>
#   <img src="lab1.png">
# </center>
#
# Some sample data:

# %% [markdown]
# ```text
# ssn           first_name   last_name
# ---           ----------   ---------
# 861103–2438   Bo           Ek
# 911212–1746   Eva          Alm
# 950829–1848   Anna         Nyström
# ...           ...          ...
#
# course_code   course_name                   level    credits
# -----------   -----------                   -----    -------
# EDA016        Programmeringsteknik          G1       7.5
# EDAA01        Programmeringsteknik - FK     G1       7.5
# EDA230        Optimerande kompilatorer      A        7.5
# ...           ...                           ...      ...
#
# ssn           course_code   grade
# ---           -----------   -----
# 861103–2438   EDA016        4
# 861103–2438   EDAA01        3
# 911212–1746   EDA016        3
# ...           ...           ...
# ```

# %% [markdown]
# The tables have been created with the following SQL
# statements:

# %% [markdown]
# ```sql
# CREATE TABLE students (
#   ssn          CHAR(11),
#   first_name   TEXT NOT NULL,
#   last_name    TEXT NOT NULL,
#   PRIMARY KEY  (ssn)
# );
#
# CREATE TABLE courses (
#   course_code   CHAR(6),
#   course_name   TEXT NOT NULL,
#   level         CHAR(2),
#   credits       DOUBLE NOT NULL CHECK (credits > 0),
#   PRIMARY KEY   (course_code)
# );
#
# CREATE TABLE taken_courses (
#   ssn           CHAR(11),
#   course_code   CHAR(6),
#   grade         INTEGER NOT NULL CHECK (grade >= 3 AND grade <= 5),
#   PRIMARY KEY   (ssn, course_code),
#   FOREIGN KEY   (ssn) REFERENCES students(ssn),
#   FOREIGN KEY   (course_code) REFERENCES courses(course_code)
# );
# ```

# %% [markdown]
# All courses offered at the "Computer Science and
# Engineering" program at LTH during the academic year 2013/14
# are in the table 'courses`. Also, the database has been
# filled with made up data. SQL statements like the following
# have been used to insert the data:

# %% [markdown]
# ```sql
# INTO   students(ssn, first_name, last_name)
# VALUES ('950705-2308', 'Anna', 'Johansson'),
#        ('930702-3582', 'Anna', 'Johansson'),
#        ('911212-1746', 'Eva', 'Alm'),
#        ('910707-3787', 'Eva', 'Nilsson'),
#        ...
# ```

# %% [markdown]
# ## Assignments
#
# As said above, this lab is designed to be run as a jupyter
# notebook. If you haven't got jupyter running, you can run
# the sql-commands for the problems below interactively inside
# sqlite3, or as a script file with all your commands, or
# inside some IDE, like [DB Browser for
# SQLite](https://sqlitebrowser.org/).
#
# If you're running the lab as a notebook (and hopefully you
# are!), evaluate the following cells before you begin:

# %%
# %load_ext sql

# %%
# %sql sqlite:///lab1.sqlite
# Out:
# 'Connected: @lab1.sqlite'

# %% [markdown]
# The tables `students`, `courses` and `taken_courses` are
# already in your database, you can see some of their contents
# by running the cells below:

# %%
# %%sql
# SELECT  *
# FROM    students
# LIMIT   4
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('950705-2308', 'Anna', 'Johansson'),
#  ('930702-3582', 'Anna', 'Johansson'),
#  ('911212-1746', 'Eva', 'Alm'),
#  ('910707-3787', 'Eva', 'Nilsson')]

# %%
# %%sql
# SELECT  *
# FROM    courses
# LIMIT   10
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('EDA016', 'Programmeringsteknik', 'G1', 7.5),
#  ('EDA031', 'C++ - programmering', 'G2', 7.5),
#  ('EDA040', 'Realtidsprogrammering', 'G2', 6.0),
#  ('EDA050', 'Operativsystem', 'G2', 4.5),
#  ('EDA070', 'Datorer och datoranvändning', 'G1', 3.0),
#  ('EDA095', 'Nätverksprogrammering', 'G2', 7.5),
#  ('EDA132', 'Tillämpad artificiell intelligens', 'G2', 7.5),
#  ('EDA180', 'Kompilatorteknik', 'G2', 7.5),
#  ('EDAF75', 'Databasteknik', 'G2', 7.5),
#  ('EDA221', 'Datorgrafik', 'G2', 7.5)]

# %%
# %%sql
# SELECT  *
# FROM    taken_courses
# LIMIT   1000
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('950705-2308', 'EITN35', 5),
#  ('950705-2308', 'ESS050', 3),
#  ('950705-2308', 'ETIN70', 4),
#  ('950705-2308', 'FMA140', 4),
#  ('950705-2308', 'MAM032', 5),
#  ('930702-3582', 'EDA040', 4),
#  ('930702-3582', 'EDA180', 4),
#  ('930702-3582', 'EDAF75', 4),
#  ('930702-3582', 'EDA260', 5),
#  ('930702-3582', 'EDA385', 3),
#  ('930702-3582', 'EDAF10', 4),
#  ('930702-3582', 'EDAN15', 5),
#  ('930702-3582', 'EDAN40', 3),
#  ('930702-3582', 'EDAN60', 3),
#  ('930702-3582', 'EEMN10', 4),
#  ('930702-3582', 'EIT140', 5),
#  ('930702-3582', 'EITF01', 5),
#  ('930702-3582', 'EITN35', 5),
#  ('930702-3582', 'ESSF10', 5),
#  ('930702-3582', 'ETIA01', 4),
#  ('930702-3582', 'ETIF10', 5),
#  ('930702-3582', 'ETIN60', 3),
#  ('930702-3582', 'ETSF10', 4),
#  ('930702-3582', 'ETT051', 4),
#  ('930702-3582', 'ETTN15', 4),
#  ('930702-3582', 'FAF150', 4),
#  ('930702-3582', 'FMA021', 5),
#  ('930702-3582', 'FMA091', 5),
#  ('930702-3582', 'FMA125', 5),
#  ('930702-3582', 'FMA140', 4),
#  ('930702-3582', 'FMAN10', 5),
#  ('930702-3582', 'FMI040', 5),
#  ('930702-3582', 'FMI050', 5),
#  ('930702-3582', 'FMS091', 3),
#  ('930702-3582', 'FMSF10', 5),
#  ('930702-3582', 'FRTN01', 3),
#  ('930702-3582', 'FRTN10', 5),
#  ('930702-3582', 'GEMA20', 3),
#  ('930702-3582', 'GEMA25', 3),
#  ('930702-3582', 'GEMA40', 4),
#  ('930702-3582', 'GEMA50', 5),
#  ('930702-3582', 'GEMA70', 5),
#  ('930702-3582', 'MAMN01', 3),
#  ('930702-3582', 'MIE080', 5),
#  ('911212-1746', 'EDA260', 5),
#  ('911212-1746', 'EDAA25', 3),
#  ('911212-1746', 'EDAF10', 4),
#  ('911212-1746', 'EDAN01', 5),
#  ('911212-1746', 'EDAN55', 5),
#  ('911212-1746', 'EDAN60', 3),
#  ('911212-1746', 'EDIN05', 4),
#  ('911212-1746', 'EEMF05', 5),
#  ('911212-1746', 'EEMN01', 4),
#  ('911212-1746', 'EIT140', 5),
#  ('911212-1746', 'EITF05', 5),
#  ('911212-1746', 'ETIF15', 5),
#  ('911212-1746', 'ETIN20', 3),
#  ('911212-1746', 'ETS052', 3),
#  ('911212-1746', 'ETS061', 3),
#  ('911212-1746', 'ETSA05', 3),
#  ('911212-1746', 'ETSN05', 3),
#  ('911212-1746', 'ETTN01', 3),
#  ('911212-1746', 'FAFF25', 5),
#  ('911212-1746', 'FMIF15', 3),
#  ('911212-1746', 'FMS155', 4),
#  ('911212-1746', 'GEMA25', 4),
#  ('911212-1746', 'GEMA55', 4),
#  ('911212-1746', 'GEMA65', 3),
#  ('911212-1746', 'MMKF15', 5),
#  ('911212-1746', 'TEK280', 4),
#  ('910707-3787', 'EDAN15', 4),
#  ('910707-3787', 'ETSN01', 3),
#  ('910707-3787', 'FMNN05', 3),
#  ('910707-3787', 'MIO022', 3),
#  ('931213-2824', 'EDA050', 4),
#  ('931213-2824', 'EDA070', 5),
#  ('931213-2824', 'EDAF05', 5),
#  ('931213-2824', 'EDAN20', 3),
#  ('931213-2824', 'EDAN60', 4),
#  ('931213-2824', 'EEMN10', 5),
#  ('931213-2824', 'EITN10', 5),
#  ('931213-2824', 'ETIN45', 5),
#  ('931213-2824', 'ETTN01', 3),
#  ('931213-2824', 'ETTN05', 5),
#  ('931213-2824', 'FMA125', 5),
#  ('931213-2824', 'FMA240', 4),
#  ('931213-2824', 'FMAF05', 4),
#  ('931213-2824', 'FMAN10', 3),
#  ('931213-2824', 'GEMA01', 4),
#  ('931213-2824', 'MAM032', 3),
#  ('931213-2824', 'MAM120', 5),
#  ('951122-1048', 'EDAN20', 4),
#  ('951122-1048', 'EDAN60', 5),
#  ('951122-1048', 'ETIA01', 3),
#  ('951122-1048', 'ETIF05', 3),
#  ('951122-1048', 'ETIN10', 5),
#  ('951122-1048', 'ETT051', 3),
#  ('951122-1048', 'FMA240', 4),
#  ('951122-1048', 'FMA430', 4),
#  ('951122-1048', 'FMIF15', 4),
#  ('951122-1048', 'FMS012', 3),
#  ('951122-1048', 'FMS072', 3),
#  ('951122-1048', 'MAM120', 3),
#  ('951122-1048', 'MAMF15', 4),
#  ('951122-1048', 'MIE080', 3),
#  ('951122-1048', 'TNX153', 4),
#  ('910308-1826', 'EDA040', 3),
#  ('910308-1826', 'EDA385', 4),
#  ('910308-1826', 'EDAN60', 5),
#  ('910308-1826', 'EITF35', 5),
#  ('910308-1826', 'ESS030', 4),
#  ('910308-1826', 'ETIN15', 4),
#  ('910308-1826', 'ETSA01', 5),
#  ('910308-1826', 'FMA021', 5),
#  ('910308-1826', 'FMA091', 5),
#  ('910308-1826', 'FMA120', 5),
#  ('910308-1826', 'FMA145', 3),
#  ('910308-1826', 'FRT010', 3),
#  ('910308-1826', 'FRTN05', 5),
#  ('941003-1225', 'EDA095', 5),
#  ('941003-1225', 'EDA180', 3),
#  ('941003-1225', 'EDAN10', 3),
#  ('941003-1225', 'FRT010', 3),
#  ('941003-1225', 'FRT041', 3),
#  ('941003-1225', 'FRTN15', 3),
#  ('941003-1225', 'GEMA20', 5),
#  ('860819-2864', 'EDAF15', 5),
#  ('860819-2864', 'EDAN55', 4),
#  ('860819-2864', 'EDI042', 3),
#  ('860819-2864', 'EIE061', 5),
#  ('860819-2864', 'EIT070', 4),
#  ('860819-2864', 'ESS050', 4),
#  ('860819-2864', 'ETIN55', 4),
#  ('860819-2864', 'ETTN10', 4),
#  ('860819-2864', 'FAFF25', 5),
#  ('860819-2864', 'FMA021', 3),
#  ('860819-2864', 'FMA140', 5),
#  ('860819-2864', 'FMI050', 3),
#  ('860819-2864', 'FMN100', 5),
#  ('860819-2864', 'FMS072', 4),
#  ('860819-2864', 'FMS091', 5),
#  ('860819-2864', 'FRT010', 4),
#  ('860819-2864', 'FRTN05', 4),
#  ('860819-2864', 'GEMA20', 3),
#  ('860819-2864', 'MAM101', 5),
#  ('870915-2742', 'EDA031', 4),
#  ('870915-2742', 'EDA132', 4),
#  ('870915-2742', 'EDA270', 4),
#  ('870915-2742', 'EDAN10', 4),
#  ('870915-2742', 'EIEN01', 5),
#  ('870915-2742', 'EITF01', 4),
#  ('870915-2742', 'EITF05', 3),
#  ('870915-2742', 'EITN30', 5),
#  ('870915-2742', 'ESS030', 5),
#  ('870915-2742', 'ETIF10', 3),
#  ('870915-2742', 'ETIN35', 5),
#  ('870915-2742', 'ETIN55', 3),
#  ('870915-2742', 'ETIN60', 3),
#  ('870915-2742', 'ETSA05', 5),
#  ('870915-2742', 'ETSF01', 5),
#  ('870915-2742', 'ETSN01', 4),
#  ('870915-2742', 'ETTN10', 4),
#  ('870915-2742', 'FMA021', 4),
#  ('870915-2742', 'FMA170', 4),
#  ('870915-2742', 'FMA200', 4),
#  ('870915-2742', 'FMI040', 3),
#  ('870915-2742', 'FMNN05', 5),
#  ('870915-2742', 'FMS012', 5),
#  ('870915-2742', 'FMSN20', 5),
#  ('870915-2742', 'FRT010', 3),
#  ('870915-2742', 'FRTN01', 3),
#  ('870915-2742', 'GEMA45', 4),
#  ('870915-2742', 'GEMA50', 3),
#  ('870915-2742', 'GEMA55', 3),
#  ('870915-2742', 'KII010', 4),
#  ('870915-2742', 'MAMN10', 4),
#  ('870915-2742', 'MAMN15', 4),
#  ('870915-2742', 'MAMN25', 5),
#  ('870915-2742', 'MIE090', 3),
#  ('870915-2742', 'MMKF15', 5),
#  ('870915-2742', 'TEK280', 4),
#  ('900227-2369', 'EDA050', 3),
#  ('900227-2369', 'EDA180', 5),
#  ('900227-2369', 'EDA230', 5),
#  ('900227-2369', 'EDA260', 5),
#  ('900227-2369', 'EDAA01', 4),
#  ('900227-2369', 'EDIN05', 4),
#  ('900227-2369', 'EIT060', 5),
#  ('900227-2369', 'EITF05', 4),
#  ('900227-2369', 'EITF20', 3),
#  ('900227-2369', 'EITN50', 4),
#  ('900227-2369', 'ETIF10', 3),
#  ('900227-2369', 'ETIN15', 5),
#  ('900227-2369', 'ETIN45', 3),
#  ('900227-2369', 'ETIN55', 5),
#  ('900227-2369', 'ETIN60', 5),
#  ('900227-2369', 'ETS170', 3),
#  ('900227-2369', 'ETSA01', 4),
#  ('900227-2369', 'ETSA05', 4),
#  ('900227-2369', 'ETSN05', 4),
#  ('900227-2369', 'ETTN05', 3),
#  ('900227-2369', 'FMA021', 3),
#  ('900227-2369', 'FMA051', 3),
#  ('900227-2369', 'FMA270', 3),
#  ('900227-2369', 'FMAF10', 3),
#  ('900227-2369', 'FMS012', 4),
#  ('900227-2369', 'FMS110', 5),
#  ('900227-2369', 'FMSF10', 3),
#  ('900227-2369', 'FMSF15', 3),
#  ('900227-2369', 'FMSN20', 5),
#  ('900227-2369', 'FRTN05', 4),
#  ('900227-2369', 'GEMA25', 4),
#  ('900227-2369', 'GEMA50', 5),
#  ('900227-2369', 'GEMA70', 4),
#  ('900227-2369', 'MAM101', 4),
#  ('900227-2369', 'MAMF15', 4),
#  ('900227-2369', 'MIO040', 5),
#  ('900227-2369', 'MIOA01', 5),
#  ('931208-3605', 'EDA050', 5),
#  ('931208-3605', 'EDAF75', 4),
#  ('931208-3605', 'EDA270', 4),
#  ('931208-3605', 'EDAF01', 5),
#  ('931208-3605', 'EDAN25', 3),
#  ('931208-3605', 'EIT020', 5),
#  ('931208-3605', 'EITN35', 4),
#  ('931208-3605', 'EITN45', 3),
#  ('931208-3605', 'EITN50', 5),
#  ('931208-3605', 'ETIF10', 3),
#  ('931208-3605', 'ETIN10', 5),
#  ('931208-3605', 'ETIN15', 5),
#  ('931208-3605', 'ETIN20', 4),
#  ('931208-3605', 'ETIN80', 3),
#  ('931208-3605', 'ETSN01', 5),
#  ('931208-3605', 'EXTA10', 4),
#  ('931208-3605', 'EXTA35', 4),
#  ('931208-3605', 'FMA270', 5),
#  ('931208-3605', 'FMNN05', 3),
#  ('931208-3605', 'FMS110', 5),
#  ('931208-3605', 'FMS155', 5),
#  ('931208-3605', 'FMSN20', 3),
#  ('931208-3605', 'FMSN30', 3),
#  ('931208-3605', 'GEMA01', 5),
#  ('931208-3605', 'GEMA25', 4),
#  ('931208-3605', 'GEMA50', 4),
#  ('931208-3605', 'GEMA65', 5),
#  ('931208-3605', 'MAMN10', 5),
#  ('931208-3605', 'MAMN25', 5),
#  ('931208-3605', 'MIE090', 4),
#  ('931208-3605', 'TEK210', 5),
#  ('931208-3605', 'TNX097', 3),
#  ('951004-2346', 'EDA095', 4),
#  ('951004-2346', 'EDA260', 5),
#  ('951004-2346', 'EDAA05', 4),
#  ('951004-2346', 'EDAF10', 4),
#  ('951004-2346', 'EDAN15', 5),
#  ('951004-2346', 'EDAN20', 5),
#  ('951004-2346', 'EDAN40', 4),
#  ('951004-2346', 'EDAN55', 4),
#  ('951004-2346', 'EDIN05', 5),
#  ('951004-2346', 'EIE061', 5),
#  ('951004-2346', 'EIEF01', 3),
#  ('951004-2346', 'EIEN01', 5),
#  ('951004-2346', 'EIT070', 3),
#  ('951004-2346', 'EIT140', 4),
#  ('951004-2346', 'EITF35', 3),
#  ('951004-2346', 'EITF40', 5),
#  ('951004-2346', 'EITN10', 4),
#  ('951004-2346', 'ETI265', 5),
#  ('951004-2346', 'ETIN10', 5),
#  ('951004-2346', 'ETIN45', 5),
#  ('951004-2346', 'ETS200', 5),
#  ('951004-2346', 'ETSF10', 4),
#  ('951004-2346', 'ETSN01', 4),
#  ('951004-2346', 'ETSN05', 3),
#  ('951004-2346', 'ETT051', 5),
#  ('951004-2346', 'EXTF60', 3),
#  ('951004-2346', 'FAFF20', 3),
#  ('951004-2346', 'FMA091', 4),
#  ('951004-2346', 'FMAF05', 5),
#  ('951004-2346', 'FMI040', 3),
#  ('951004-2346', 'FMIF15', 5),
#  ('951004-2346', 'FMNN05', 3),
#  ('951004-2346', 'FMS091', 5),
#  ('951004-2346', 'FMS110', 3),
#  ('951004-2346', 'FMSF15', 3),
#  ('951004-2346', 'FMSN30', 3),
#  ('951004-2346', 'FRT010', 3),
#  ('951004-2346', 'FRTN15', 5),
#  ('951004-2346', 'GEMA25', 4),
#  ('951004-2346', 'GEMA65', 4),
#  ('951004-2346', 'MAM101', 4),
#  ('951004-2346', 'MAMN10', 3),
#  ('951004-2346', 'MIO012', 5),
#  ('951004-2346', 'MIO022', 3),
#  ('951004-2346', 'MMKF15', 5),
#  ('951004-2346', 'TNX097', 5),
#  ('910915-2068', 'EDA031', 4),
#  ('910915-2068', 'EDA040', 5),
#  ('910915-2068', 'EDA221', 5),
#  ('910915-2068', 'EDA230', 5),
#  ('910915-2068', 'EDA260', 4),
#  ('910915-2068', 'EDA385', 5),
#  ('910915-2068', 'EDAA25', 3),
#  ('910915-2068', 'EDAF01', 4),
#  ('910915-2068', 'EDAF05', 4),
#  ('910915-2068', 'EDAN01', 3),
#  ('910915-2068', 'EDAN15', 4),
#  ('910915-2068', 'EDAN35', 4),
#  ('910915-2068', 'EDAN40', 5),
#  ('910915-2068', 'EDAN50', 5),
#  ('910915-2068', 'EDIN01', 4),
#  ('910915-2068', 'EITF05', 4),
#  ('910915-2068', 'EITF20', 4),
#  ('910915-2068', 'ETIF05', 4),
#  ('910915-2068', 'ETIN10', 3),
#  ('910915-2068', 'ETIN15', 3),
#  ('910915-2068', 'ETS052', 3),
#  ('910915-2068', 'ETS170', 5),
#  ('910915-2068', 'ETSF10', 5),
#  ('910915-2068', 'FAFF20', 4),
#  ('910915-2068', 'FMA091', 3),
#  ('910915-2068', 'FMA125', 5),
#  ('910915-2068', 'FMA170', 5),
#  ('910915-2068', 'FMA200', 5),
#  ('910915-2068', 'FMA240', 5),
#  ('910915-2068', 'FMA270', 3),
#  ('910915-2068', 'FMAF05', 5),
#  ('910915-2068', 'FMI050', 3),
#  ('910915-2068', 'FMS091', 5),
#  ('910915-2068', 'FMS155', 3),
#  ('910915-2068', 'FMSF10', 4),
#  ('910915-2068', 'FMSN20', 3),
#  ('910915-2068', 'FMSN30', 4),
#  ('910915-2068', 'FRTN01', 4),
#  ('910915-2068', 'GEMA40', 3),
#  ('910915-2068', 'GEMA70', 4),
#  ('910915-2068', 'MAM101', 5),
#  ('910915-2068', 'MAMN15', 4),
#  ('910915-2068', 'MAMN25', 5),
#  ('910915-2068', 'MIE080', 3),
#  ('910915-2068', 'MIE090', 5),
#  ('910915-2068', 'MIOA01', 4),
#  ('910915-2068', 'MMKF15', 5),
#  ('910915-2068', 'TEK280', 5),
#  ('860206-1065', 'EDA221', 4),
#  ('860206-1065', 'EDAF10', 5),
#  ('860206-1065', 'EDI042', 4),
#  ('860206-1065', 'EITF01', 4),
#  ('860206-1065', 'EITF05', 3),
#  ('860206-1065', 'ESSF10', 3),
#  ('860206-1065', 'ETS200', 4),
#  ('860206-1065', 'ETSF01', 4),
#  ('860206-1065', 'ETSN01', 5),
#  ('860206-1065', 'EXTA10', 4),
#  ('860206-1065', 'FMA135', 3),
#  ('860206-1065', 'FMA170', 4),
#  ('860206-1065', 'FMA175', 4),
#  ('860206-1065', 'FMA430', 3),
#  ('860206-1065', 'FMAA01', 5),
#  ('860206-1065', 'FMI040', 5),
#  ('860206-1065', 'FMS051', 5),
#  ('860206-1065', 'FMS091', 3),
#  ('860206-1065', 'FRT010', 4),
#  ('860206-1065', 'FRT041', 4),
#  ('860206-1065', 'MMKF15', 4),
#  ('860206-1065', 'TEK280', 5),
#  ('900528-1540', 'EDA050', 3),
#  ('900528-1540', 'EDAN50', 4),
#  ('900528-1540', 'EITN10', 5),
#  ('900528-1540', 'FAFF20', 5),
#  ('900528-1540', 'FMA120', 5),
#  ('900528-1540', 'FMA135', 3),
#  ('900528-1540', 'MAM032', 4),
#  ('900528-1540', 'MAMN25', 3),
#  ('900528-1540', 'MIO040', 3),
#  ('900528-1540', 'TEK210', 4),
#  ('930502-2040', 'EDA221', 4),
#  ('930502-2040', 'EDAF10', 4),
#  ('930502-2040', 'EDAN01', 3),
#  ('930502-2040', 'EEM031', 3),
#  ('930502-2040', 'EIT140', 4),
#  ('930502-2040', 'ESS030', 4),
#  ('930502-2040', 'ETIA01', 3),
#  ('930502-2040', 'ETIA10', 5),
#  ('930502-2040', 'ETIF10', 3),
#  ('930502-2040', 'ETIF15', 5),
#  ('930502-2040', 'ETIN55', 5),
#  ('930502-2040', 'ETS200', 5),
#  ('930502-2040', 'ETSF01', 4),
#  ('930502-2040', 'ETSN01', 4),
#  ('930502-2040', 'ETT051', 5),
#  ('930502-2040', 'FMA051', 5),
#  ('930502-2040', 'FMA125', 3),
#  ('930502-2040', 'FMA135', 5),
#  ('930502-2040', 'FMA430', 4),
#  ('930502-2040', 'FMI040', 5),
#  ('930502-2040', 'FMSF15', 3),
#  ('930502-2040', 'FMSN20', 5),
#  ('930502-2040', 'FRTN05', 4),
#  ('930502-2040', 'GEMA45', 3),
#  ('930502-2040', 'GEMA70', 5),
#  ('930502-2040', 'MAM120', 4),
#  ('930502-2040', 'MIO012', 3),
#  ('950317-3520', 'EEMN10', 4),
#  ('950317-3520', 'FMA051', 4),
#  ('950317-3520', 'FMNN25', 5),
#  ('950317-3520', 'FRT041', 4),
#  ('950317-3520', 'GEMA60', 4),
#  ('950317-3520', 'MAMN25', 3),
#  ('891021-1287', 'EDA016', 3),
#  ('891021-1287', 'EDA070', 4),
#  ('891021-1287', 'EDA230', 3),
#  ('891021-1287', 'EDAF05', 3),
#  ('891021-1287', 'EDAN20', 5),
#  ('891021-1287', 'EDIN05', 3),
#  ('891021-1287', 'EEM031', 3),
#  ('891021-1287', 'EEMF05', 4),
#  ('891021-1287', 'EIEN01', 5),
#  ('891021-1287', 'EIT070', 5),
#  ('891021-1287', 'EIT140', 4),
#  ('891021-1287', 'EITF05', 4),
#  ('891021-1287', 'ETIN15', 3),
#  ('891021-1287', 'ETIN40', 4),
#  ('891021-1287', 'ETIN55', 3),
#  ('891021-1287', 'ETS052', 3),
#  ('891021-1287', 'ETS075', 4),
#  ('891021-1287', 'ETS200', 4),
#  ('891021-1287', 'ETSA05', 3),
#  ('891021-1287', 'ETSF10', 3),
#  ('891021-1287', 'ETTN05', 4),
#  ('891021-1287', 'FAF150', 3),
#  ('891021-1287', 'FMA170', 3),
#  ('891021-1287', 'FMA272', 4),
#  ('891021-1287', 'FMAA01', 3),
#  ('891021-1287', 'FMAF01', 5),
#  ('891021-1287', 'FMNN25', 4),
#  ('891021-1287', 'FRT041', 4),
#  ('891021-1287', 'FRT130', 3),
#  ('891021-1287', 'FRTN10', 3),
#  ('891021-1287', 'GEMA40', 5),
#  ('891021-1287', 'GEMA65', 3),
#  ('891021-1287', 'MAM032', 3),
#  ('891021-1287', 'MAMN01', 5),
#  ('891021-1287', 'MAMN10', 3),
#  ('891021-1287', 'MIE080', 4),
#  ('891021-1287', 'MIO012', 4),
#  ('891021-1287', 'MIOA01', 4),
#  ('891021-1287', 'TEK210', 3),
#  ('880620-2564', 'EDA132', 4),
#  ('880620-2564', 'EDA180', 3),
#  ('880620-2564', 'EDA221', 5),
#  ('880620-2564', 'EDA385', 4),
#  ('880620-2564', 'EDAA25', 3),
#  ('880620-2564', 'EDAF01', 3),
#  ('880620-2564', 'EDAF10', 4),
#  ('880620-2564', 'EDAN35', 3),
#  ('880620-2564', 'EDAN40', 3),
#  ('880620-2564', 'EDIN01', 3),
#  ('880620-2564', 'EEMF05', 4),
#  ('880620-2564', 'EEMN15', 4),
#  ('880620-2564', 'EIT020', 5),
#  ('880620-2564', 'EITF35', 4),
#  ('880620-2564', 'ETIF10', 5),
#  ('880620-2564', 'ETIN55', 4),
#  ('880620-2564', 'ETS061', 4),
#  ('880620-2564', 'ETSF10', 5),
#  ('880620-2564', 'ETTN05', 5),
#  ('880620-2564', 'ETTN15', 4),
#  ('880620-2564', 'EXTA10', 4),
#  ('880620-2564', 'EXTF60', 4),
#  ('880620-2564', 'FMA051', 5),
#  ('880620-2564', 'FMA125', 4),
#  ('880620-2564', 'FMA140', 4),
#  ('880620-2564', 'FMA200', 4),
#  ('880620-2564', 'FMA272', 4),
#  ('880620-2564', 'FMA420', 5),
#  ('880620-2564', 'FMAF05', 3),
#  ('880620-2564', 'FMN011', 3),
#  ('880620-2564', 'FMNN05', 3),
#  ('880620-2564', 'FMS072', 5),
#  ('880620-2564', 'FMSF15', 4),
#  ('880620-2564', 'FMSN20', 3),
#  ('880620-2564', 'FRTN01', 3),
#  ('880620-2564', 'FRTN05', 4),
#  ('880620-2564', 'FRTN15', 4),
#  ('880620-2564', 'GEMA01', 4),
#  ('880620-2564', 'GEMA25', 5),
#  ('880620-2564', 'GEMA45', 5),
#  ('880620-2564', 'GEMA60', 3),
#  ('880620-2564', 'GEMA65', 5),
#  ('880620-2564', 'KII010', 3),
#  ('880620-2564', 'MAM032', 5),
#  ('880620-2564', 'MAMN01', 4),
#  ('880620-2564', 'MIE080', 4),
#  ('880620-2564', 'MIE090', 4),
#  ('880620-2564', 'MIO012', 3),
#  ('880620-2564', 'MIOA01', 4),
#  ('880620-2564', 'TEK210', 5),
#  ('940802-3861', 'EDA270', 3),
#  ('940802-3861', 'EDAN55', 3),
#  ('940802-3861', 'ESS030', 5),
#  ('940802-3861', 'ETIF10', 4),
#  ('940802-3861', 'ETSF10', 5),
#  ('940802-3861', 'ETTN10', 3),
#  ('940802-3861', 'EXTA10', 5),
#  ('940802-3861', 'FMA021', 4),
#  ('940802-3861', 'FMA272', 4),
#  ('940802-3861', 'FMA430', 3),
#  ('940802-3861', 'FMAN10', 5),
#  ('940802-3861', 'FMN011', 4),
#  ('940802-3861', 'FMSF10', 4),
#  ('940802-3861', 'FMSF15', 5),
#  ('940802-3861', 'FMSN35', 3),
#  ('940802-3861', 'FRT010', 5),
#  ('940802-3861', 'GEMA45', 5),
#  ('940802-3861', 'GEMA55', 3),
#  ('940802-3861', 'GEMA65', 3),
#  ('850706-2762', 'EEMN10', 4),
#  ('850706-2762', 'ETI265', 5),
#  ('850706-2762', 'MAM101', 3),
#  ('850706-2762', 'MMKF15', 3),
#  ('890622-1928', 'EDA180', 5),
#  ('890622-1928', 'EDAF75', 4),
#  ('890622-1928', 'EDA221', 3),
#  ('890622-1928', 'EDAN15', 5),
#  ('890622-1928', 'EDAN20', 3),
#  ('890622-1928', 'EDAN30', 3),
#  ('890622-1928', 'EDAN40', 5),
#  ('890622-1928', 'EDIN05', 3),
#  ('890622-1928', 'EIE061', 3),
#  ('890622-1928', 'EIEF01', 5),
#  ('890622-1928', 'EIT070', 4),
#  ('890622-1928', 'EIT140', 4),
#  ('890622-1928', 'EITF40', 5),
#  ('890622-1928', 'EITN45', 4),
#  ('890622-1928', 'EITN50', 3),
#  ('890622-1928', 'ETI265', 5),
#  ('890622-1928', 'ETS075', 3),
#  ('890622-1928', 'ETS200', 4),
#  ('890622-1928', 'FMAN10', 3),
#  ('890622-1928', 'FMIF15', 3),
#  ('890622-1928', 'FRTN10', 4),
#  ('890622-1928', 'GEMA65', 5),
#  ('890622-1928', 'MAMF15', 5),
#  ('890622-1928', 'MAMN25', 5),
#  ('890622-1928', 'MIE090', 5),
#  ('890622-1928', 'MIO012', 5),
#  ('890622-1928', 'MMKF15', 5),
#  ('890622-1928', 'TEK280', 5),
#  ('910226-3409', 'EDA180', 5),
#  ('910226-3409', 'EDA221', 5),
#  ('910226-3409', 'EEMF05', 3),
#  ('910226-3409', 'ETIN35', 5),
#  ('910226-3409', 'ETIN60', 3),
#  ('910226-3409', 'FMA175', 3),
#  ('910226-3409', 'FMS072', 5),
#  ('910226-3409', 'FMS110', 3),
#  ('910226-3409', 'MAMN25', 5),
#  ('861103-2438', 'EDAA25', 4),
#  ('861103-2438', 'EDAF05', 3),
#  ('861103-2438', 'EDAF10', 3),
#  ('861103-2438', 'EDAF15', 4),
#  ('861103-2438', 'EDAN55', 3),
#  ('861103-2438', 'EIEF01', 4),
#  ('861103-2438', 'EITN50', 5),
#  ('861103-2438', 'ETI265', 5),
#  ('861103-2438', 'ETIN20', 5),
#  ('861103-2438', 'ETIN55', 5),
#  ('861103-2438', 'FAF150', 5),
#  ('861103-2438', 'FMA135', 5),
#  ('861103-2438', 'FMAA01', 4),
#  ('861103-2438', 'FMI040', 5),
#  ('861103-2438', 'FMIF15', 5),
#  ('861103-2438', 'FMNN05', 5),
#  ('861103-2438', 'FRT010', 4),
#  ('861103-2438', 'FRTN01', 5),
#  ('861103-2438', 'GEMA25', 3),
#  ('861103-2438', 'MIOA01', 5),
#  ('850819-2139', 'EDA385', 4),
#  ('850819-2139', 'EDAF01', 5),
#  ('850819-2139', 'EDAF05', 4),
#  ('850819-2139', 'ETSA05', 4),
#  ('850819-2139', 'EXTA10', 3),
#  ('850819-2139', 'FAF150', 3),
#  ('850819-2139', 'FMA125', 4),
#  ('850819-2139', 'FMA200', 4),
#  ('850819-2139', 'FMAA01', 3),
#  ('850819-2139', 'FMNN05', 5),
#  ('850819-2139', 'FMS091', 4),
#  ('850819-2139', 'GEMA40', 5),
#  ('940825-1934', 'EDA031', 3),
#  ('940825-1934', 'EDIN05', 3),
#  ('940825-1934', 'EEMN10', 4),
#  ('940825-1934', 'EIE061', 5),
#  ('940825-1934', 'EIEN01', 3),
#  ('940825-1934', 'EITF35', 4),
#  ('940825-1934', 'EITN10', 3),
#  ('940825-1934', 'ETIN10', 5),
#  ('940825-1934', 'ETIN15', 3),
#  ('940825-1934', 'ETTN10', 3),
#  ('940825-1934', 'FMAN10', 3),
#  ('940825-1934', 'FRTN01', 5),
#  ('940825-1934', 'GEMA25', 4),
#  ('940825-1934', 'GEMA45', 4),
#  ('940825-1934', 'KII010', 5),
#  ('940825-1934', 'TEK210', 5),
#  ('860323-1071', 'EDA050', 4),
#  ('860323-1071', 'EDAN20', 3),
#  ('860323-1071', 'ETIA01', 5),
#  ('860323-1071', 'ETIN80', 3),
#  ('860323-1071', 'FMN100', 4),
#  ('860323-1071', 'FMSN30', 4),
#  ('860323-1071', 'FRTN01', 4),
#  ('860323-1071', 'GEMA55', 5),
#  ('860323-1071', 'MIE080', 5),
#  ('860323-1071', 'MIO040', 4),
#  ('920308-3854', 'EDA016', 4),
#  ('920308-3854', 'EDA050', 3),
#  ('920308-3854', 'EDA095', 4),
#  ('920308-3854', 'EDA132', 3),
#  ('920308-3854', 'EDA180', 5),
#  ('920308-3854', 'EDA230', 4),
#  ('920308-3854', 'EDAA25', 5),
#  ('920308-3854', 'EDAN10', 3),
#  ('920308-3854', 'EDAN35', 5),
#  ('920308-3854', 'EDAN40', 5),
#  ('920308-3854', 'EDAN55', 4),
#  ('920308-3854', 'EEMN10', 3),
#  ('920308-3854', 'EIT070', 4),
#  ('920308-3854', 'EITF01', 4),
#  ('920308-3854', 'EITF20', 5),
#  ('920308-3854', 'EITF40', 4),
#  ('920308-3854', 'EITN30', 3),
#  ('920308-3854', 'ESS050', 5),
#  ('920308-3854', 'ETIN15', 4),
#  ('920308-3854', 'ETS200', 5),
#  ('920308-3854', 'ETSF01', 5),
#  ('920308-3854', 'ETSF10', 5),
#  ('920308-3854', 'ETTN01', 4),
#  ('920308-3854', 'ETTN10', 3),
#  ('920308-3854', 'EXTA35', 4),
#  ('920308-3854', 'FMA111', 5),
#  ('920308-3854', 'FMA125', 5),
#  ('920308-3854', 'FMA170', 5),
#  ('920308-3854', 'FMA200', 4),
#  ('920308-3854', 'FMA240', 4),
#  ('920308-3854', 'FMA272', 3),
#  ('920308-3854', 'FMI040', 5),
#  ('920308-3854', 'FMN100', 5),
#  ('920308-3854', 'FMS091', 3),
#  ('920308-3854', 'FMS110', 5),
#  ('920308-3854', 'FMS155', 5),
#  ('920308-3854', 'FRT041', 3),
#  ('920308-3854', 'GEMA20', 5),
#  ('920308-3854', 'GEMA65', 3),
#  ('920308-3854', 'MAM120', 4),
#  ('920308-3854', 'MAMN15', 3),
#  ('890820-2496', 'EDA260', 5),
#  ('890820-2496', 'EDA385', 4),
#  ('890820-2496', 'EDAF15', 5),
#  ('890820-2496', 'EDAN20', 4),
#  ('890820-2496', 'EDAN35', 4),
#  ('890820-2496', 'EDI042', 3),
#  ('890820-2496', 'EEMN01', 3),
#  ('890820-2496', 'EEMN15', 5),
#  ('890820-2496', 'EITN30', 3),
#  ('890820-2496', 'EITN40', 5),
#  ('890820-2496', 'ETIF05', 3),
#  ('890820-2496', 'EXTA35', 3),
#  ('890820-2496', 'FMA272', 5),
#  ('890820-2496', 'FMA430', 5),
#  ('890820-2496', 'FMAF10', 4),
#  ('890820-2496', 'FMS091', 4),
#  ('890820-2496', 'FMSN20', 4),
#  ('890820-2496', 'FMSN30', 5),
#  ('890820-2496', 'FRTN15', 5),
#  ('890820-2496', 'GEMA25', 5),
#  ('890820-2496', 'GEMA55', 3),
#  ('890820-2496', 'MAM101', 5),
#  ('890820-2496', 'MAMN15', 4),
#  ('890820-2496', 'MIE090', 3),
#  ('920623-3258', 'EDA016', 4),
#  ('920623-3258', 'EDA095', 5),
#  ('920623-3258', 'EDAA01', 3),
#  ('920623-3258', 'EDAF10', 5),
#  ('920623-3258', 'EDAN15', 4),
#  ('920623-3258', 'EDAN30', 3),
#  ('920623-3258', 'EDAN55', 5),
#  ('920623-3258', 'EDAN60', 4),
#  ('920623-3258', 'EDIN05', 4),
#  ('920623-3258', 'EEMN10', 3),
#  ('920623-3258', 'EIE061', 4),
#  ('920623-3258', 'EIT020', 3),
#  ('920623-3258', 'EIT140', 3),
#  ('920623-3258', 'EITF20', 5),
#  ('920623-3258', 'EITF40', 4),
#  ('920623-3258', 'ESSF10', 4),
#  ('920623-3258', 'ETIA01', 5),
#  ('920623-3258', 'ETIA10', 4),
#  ('920623-3258', 'ETIF15', 5),
#  ('920623-3258', 'ETIN15', 5),
#  ('920623-3258', 'ETIN40', 3),
#  ('920623-3258', 'ETIN45', 3),
#  ('920623-3258', 'ETIN55', 5),
#  ('920623-3258', 'ETS061', 3),
#  ('920623-3258', 'ETS170', 5),
#  ('920623-3258', 'ETSN05', 3),
#  ('920623-3258', 'ETTN01', 3),
#  ('920623-3258', 'FMA140', 5),
#  ('920623-3258', 'FMA270', 3),
#  ('920623-3258', 'FMA272', 4),
#  ('920623-3258', 'FMA430', 4),
#  ('920623-3258', 'FMAF10', 3),
#  ('920623-3258', 'FMS091', 4),
#  ('920623-3258', 'FMSN20', 3),
#  ('920623-3258', 'FRT041', 3),
#  ('920623-3258', 'FRTN01', 5),
#  ('920623-3258', 'GEMA25', 5),
#  ('920623-3258', 'GEMA55', 5),
#  ('920623-3258', 'GEMA60', 4),
#  ('920623-3258', 'GEMA65', 3),
#  ('920623-3258', 'MAM032', 5),
#  ('920623-3258', 'MAM120', 4),
#  ('920623-3258', 'MAMN01', 5),
#  ('920623-3258', 'MIE080', 4),
#  ('920623-3258', 'MMKF15', 4),
#  ('920623-3258', 'TEK280', 4),
#  ('890621-3057', 'EDA016', 3),
#  ('890621-3057', 'EDA031', 5),
#  ('890621-3057', 'EDA132', 4),
#  ('890621-3057', 'EDA230', 4),
#  ('890621-3057', 'EDAF10', 4),
#  ('890621-3057', 'EDAF15', 3),
#  ('890621-3057', 'EDAN20', 5),
#  ('890621-3057', 'EDAN30', 5),
#  ('890621-3057', 'EDAN35', 5),
#  ('890621-3057', 'EDI042', 4),
#  ('890621-3057', 'EDIN05', 4),
#  ('890621-3057', 'EEMN15', 3),
#  ('890621-3057', 'EIT060', 5),
#  ('890621-3057', 'EITF35', 5),
#  ('890621-3057', 'ESS030', 3),
#  ('890621-3057', 'ETIF05', 3),
#  ('890621-3057', 'ETIF15', 3),
#  ('890621-3057', 'ETIN35', 4),
#  ('890621-3057', 'ETSA05', 4),
#  ('890621-3057', 'ETTN01', 4),
#  ('890621-3057', 'ETTN05', 5),
#  ('890621-3057', 'EXTF60', 3),
#  ('890621-3057', 'FMA051', 4),
#  ('890621-3057', 'FMA125', 3),
#  ('890621-3057', 'FMA145', 5),
#  ('890621-3057', 'FMA240', 4),
#  ('890621-3057', 'FMA270', 3),
#  ('890621-3057', 'FMAA01', 5),
#  ('890621-3057', 'FMNN05', 5),
#  ('890621-3057', 'FMSN30', 5),
#  ('890621-3057', 'FMSN35', 4),
#  ('890621-3057', 'FRTN10', 5),
#  ('890621-3057', 'GEMA01', 5),
#  ('890621-3057', 'GEMA25', 3),
#  ('890621-3057', 'GEMA50', 5),
#  ('890621-3057', 'MAMF15', 3),
#  ('890621-3057', 'MAMN01', 5),
#  ('890621-3057', 'MAMN25', 5),
#  ('890621-3057', 'MIE090', 4),
#  ('890621-3057', 'MIO022', 5),
#  ('890621-3057', 'MIOA01', 4),
#  ('920812-1857', 'EDAN01', 4),
#  ('920812-1857', 'EEMN01', 3),
#  ('920812-1857', 'EITN40', 5),
#  ('920812-1857', 'ETIF15', 4),
#  ('920812-1857', 'FMA175', 4),
#  ('920812-1857', 'MAM101', 5),
#  ('850208-1213', 'EDAF75', 3),
#  ('850208-1213', 'EDAA01', 3),
#  ('850208-1213', 'EDAN35', 3),
#  ('850208-1213', 'EDI042', 5),
#  ('850208-1213', 'EIEN01', 3),
#  ('850208-1213', 'EITF01', 4),
#  ('850208-1213', 'EITN50', 5),
#  ('850208-1213', 'ETIN15', 5),
#  ('850208-1213', 'ETIN45', 3),
#  ('850208-1213', 'ETIN60', 4),
#  ('850208-1213', 'ETSA05', 3),
#  ('850208-1213', 'EXTF60', 4),
#  ('850208-1213', 'FMA420', 3),
#  ('850208-1213', 'FMA430', 5),
#  ('850208-1213', 'FMAF05', 4),
#  ('850208-1213', 'FMI040', 3),
#  ('850208-1213', 'FRT130', 4),
#  ('850208-1213', 'GEMA20', 3),
#  ('850208-1213', 'MAMN25', 3),
#  ('850208-1213', 'MIOA01', 5),
#  ('850208-1213', 'MMKF15', 3),
#  ('850208-1213', 'TNX153', 4),
#  ('930420-2833', 'EITF05', 4),
#  ('930716-3933', 'EDAN15', 4),
#  ('930716-3933', 'EDAN55', 4),
#  ('930716-3933', 'ETIN10', 3),
#  ('930716-3933', 'FMAA01', 4),
#  ('930716-3933', 'FMSN20', 5),
#  ('930716-3933', 'FRTN10', 5),
#  ('930716-3933', 'MAM101', 3),
#  ('940801-2971', 'EDA050', 3),
#  ('940801-2971', 'EDA180', 5),
#  ('940801-2971', 'EDIN01', 4),
#  ('940801-2971', 'EITF01', 4),
#  ('940801-2971', 'EITN10', 4),
#  ('940801-2971', 'EITN50', 5),
#  ('940801-2971', 'ESSF10', 5),
#  ('940801-2971', 'ETIN55', 5),
#  ('940801-2971', 'ETSF01', 3),
#  ('940801-2971', 'ETT051', 5),
#  ('940801-2971', 'ETTN10', 3),
#  ('940801-2971', 'FMA051', 3),
#  ('940801-2971', 'FMA145', 5),
#  ('940801-2971', 'FMNN05', 5),
#  ('940801-2971', 'FMS155', 5),
#  ('940801-2971', 'FMSF15', 3),
#  ('940801-2971', 'FRT041', 3),
#  ('940801-2971', 'FRTN01', 4),
#  ('940801-2971', 'GEMA25', 4),
#  ('940801-2971', 'MAM032', 4),
#  ('940801-2971', 'MAMN01', 5),
#  ('940801-2971', 'MAMN15', 5),
#  ('940801-2971', 'MMKF15', 4),
#  ('931128-1333', 'EDA016', 3),
#  ('931128-1333', 'EDAN15', 3),
#  ('931128-1333', 'EDAN55', 3),
#  ('931128-1333', 'EEMN10', 4),
#  ('931128-1333', 'EIT070', 4),
#  ('931128-1333', 'EITF05', 3),
#  ('931128-1333', 'EITF40', 5),
#  ('931128-1333', 'ETIA01', 3),
#  ('931128-1333', 'ETIN60', 3),
#  ('931128-1333', 'ETS170', 3),
#  ('931128-1333', 'ETS200', 5),
#  ('931128-1333', 'ETSA01', 3),
#  ('931128-1333', 'ETSN01', 4),
#  ('931128-1333', 'ETTN10', 4),
#  ('931128-1333', 'ETTN15', 5),
#  ('931128-1333', 'FMA051', 4),
#  ('931128-1333', 'FMA135', 4),
#  ('931128-1333', 'FMA140', 4),
#  ('931128-1333', 'FMA240', 3),
#  ('931128-1333', 'FMN011', 4),
#  ('931128-1333', 'FMS051', 4),
#  ('931128-1333', 'GEMA60', 4),
#  ('931128-1333', 'MAMN15', 4),
#  ('931128-1333', 'MAMN25', 5),
#  ('931128-1333', 'MIO022', 4),
#  ('940318-2373', 'EDA095', 3),
#  ('940318-2373', 'EDAF01', 5),
#  ('940318-2373', 'EDAN01', 4),
#  ('940318-2373', 'EIT020', 5),
#  ('940318-2373', 'EIT070', 4),
#  ('940318-2373', 'EITF01', 4),
#  ('940318-2373', 'EITF05', 5),
#  ('940318-2373', 'EITF40', 5),
#  ('940318-2373', 'ETIA01', 5),
#  ('940318-2373', 'ETIN10', 4),
#  ('940318-2373', 'ETIN60', 5),
#  ('940318-2373', 'ETS170', 5),
#  ('940318-2373', 'ETSF01', 3),
#  ('940318-2373', 'ETT051', 4),
#  ('940318-2373', 'EXTA10', 3),
#  ('940318-2373', 'FAF150', 4),
#  ('940318-2373', 'FMA091', 5),
#  ('940318-2373', 'FMA140', 3),
#  ('940318-2373', 'FMA420', 4),
#  ('940318-2373', 'FMAN10', 5),
#  ('940318-2373', 'FMI040', 5),
#  ('940318-2373', 'FMNN25', 4),
#  ('940318-2373', 'FMS091', 4),
#  ('940318-2373', 'FMSN30', 3),
#  ('940318-2373', 'FRT130', 3),
#  ('940318-2373', 'GEMA01', 4),
#  ('940318-2373', 'GEMA65', 4),
#  ('940318-2373', 'GEMA70', 4),
#  ('940318-2373', 'MAM032', 4),
#  ('940318-2373', 'MIE080', 4),
#  ('940318-2373', 'MIO022', 3),
#  ('940318-2373', 'TNX153', 3),
#  ('881030-2772', 'EDA260', 3),
#  ('881030-2772', 'EDAN30', 3),
#  ('881030-2772', 'EEMF05', 4),
#  ('881030-2772', 'ETIN55', 5),
#  ('881030-2772', 'ETS170', 3),
#  ('881030-2772', 'ETSA05', 4),
#  ('881030-2772', 'ETT051', 3),
#  ('881030-2772', 'FAFF25', 5),
#  ('881030-2772', 'FMA240', 4),
#  ('881030-2772', 'FMA272', 5),
#  ('881030-2772', 'FMA430', 4),
#  ('881030-2772', 'FMAF01', 4),
#  ('881030-2772', 'FMI050', 3),
#  ('881030-2772', 'FMIF15', 5),
#  ('881030-2772', 'FMS091', 3),
#  ('881030-2772', 'FMSF10', 3),
#  ('881030-2772', 'FRT041', 3),
#  ('881030-2772', 'FRT090', 5),
#  ('881030-2772', 'MAMN01', 5),
#  ('931015-1271', 'EDA230', 4),
#  ('931015-1271', 'ETIN20', 4),
#  ('931015-1271', 'ETIN40', 4),
#  ('900206-3735', 'EDA221', 5),
#  ('900206-3735', 'EDAF10', 4),
#  ('900206-3735', 'EDAN30', 5),
#  ('900206-3735', 'EDAN55', 3),
#  ('900206-3735', 'EEMN15', 3),
#  ('900206-3735', 'EIEF01', 4),
#  ('900206-3735', 'EITN40', 4),
#  ('900206-3735', 'ETIF10', 4),
#  ('900206-3735', 'ETSA01', 5),
#  ('900206-3735', 'FMA145', 3),
#  ('900206-3735', 'FMNN25', 5),
#  ('900206-3735', 'FMS051', 5),
#  ('900206-3735', 'FMS072', 4),
#  ('900206-3735', 'FRT041', 5),
#  ('900206-3735', 'FRTN10', 5),
#  ('900206-3735', 'GEMA20', 4),
#  ('900206-3735', 'GEMA25', 3),
#  ('900206-3735', 'GEMA50', 5),
#  ('900206-3735', 'MAMN10', 4),
#  ('900206-3735', 'TNX097', 3),
#  ('891231-2554', 'EDAN10', 4),
#  ('891231-2554', 'EDAN25', 5),
#  ('891231-2554', 'EIEF01', 5),
#  ('891231-2554', 'EITF20', 3),
#  ('891231-2554', 'ETIN35', 4),
#  ('891231-2554', 'FMA111', 3),
#  ('891231-2554', 'FMA125', 3),
#  ('891231-2554', 'FMA145', 4),
#  ('891231-2554', 'FRT041', 3),
#  ('891231-2554', 'FRT130', 4),
#  ('891231-2554', 'FRTN15', 5),
#  ('891231-2554', 'TNX153', 4),
#  ('900526-1450', 'EDA031', 4),
#  ('900526-1450', 'FMA091', 3),
#  ('900526-1450', 'FRTN01', 4),
#  ('900526-1450', 'MAMN15', 5),
#  ('950830-2637', 'EDAA05', 3),
#  ('950830-2637', 'EDAF01', 4),
#  ('950830-2637', 'EDAN10', 5),
#  ('950830-2637', 'EDIN01', 4),
#  ('950830-2637', 'EIE061', 5),
#  ('950830-2637', 'EIEN01', 5),
#  ('950830-2637', 'EITN10', 5),
#  ('950830-2637', 'EITN35', 4),
#  ('950830-2637', 'ETIF05', 3),
#  ('950830-2637', 'ETIN60', 3),
#  ('950830-2637', 'ETIN70', 4),
#  ('950830-2637', 'ETSA05', 5),
#  ('950830-2637', 'ETTN15', 5),
#  ('950830-2637', 'EXTA10', 3),
#  ('950830-2637', 'EXTA35', 3),
#  ('950830-2637', 'EXTF60', 3),
#  ('950830-2637', 'FMA021', 3),
#  ('950830-2637', 'FMA051', 5),
#  ('950830-2637', 'FMAF10', 4),
#  ('950830-2637', 'FMI050', 3),
#  ('950830-2637', 'FMSF10', 5),
#  ('950830-2637', 'FMSF15', 5),
#  ('950830-2637', 'FRT010', 3),
#  ('880322-3951', 'EDA016', 4),
#  ('880322-3951', 'EDA040', 3),
#  ('880322-3951', 'EDAN10', 5),
#  ('880322-3951', 'EDAN25', 3),
#  ('880322-3951', 'EDAN60', 3),
#  ('880322-3951', 'EEMN10', 3),
#  ('880322-3951', 'EIT070', 3),
#  ('880322-3951', 'EIT140', 4),
#  ('880322-3951', 'EITF01', 5),
#  ('880322-3951', 'EITN40', 4),
#  ('880322-3951', 'ESSF10', 4),
#  ('880322-3951', 'ETIF10', 5),
#  ('880322-3951', 'ETIN20', 4),
#  ('880322-3951', 'ETIN60', 3),
#  ('880322-3951', 'ETS170', 3),
#  ('880322-3951', 'ETSF10', 4),
#  ('880322-3951', 'ETTN15', 4),
#  ('880322-3951', 'EXTF60', 5),
#  ('880322-3951', 'FAF150', 3),
#  ('880322-3951', 'FMA091', 5),
#  ('880322-3951', 'FMA145', 4),
#  ('880322-3951', 'FMA272', 4),
#  ('880322-3951', 'FMAF10', 4),
#  ('880322-3951', 'FMNN05', 5),
#  ('880322-3951', 'FMS091', 3),
#  ('880322-3951', 'FMSF10', 4),
#  ('880322-3951', 'FMSN20', 4),
#  ('880322-3951', 'FRTN01', 5),
#  ('880322-3951', 'FRTN10', 4),
#  ('880322-3951', 'FRTN15', 4),
#  ('880322-3951', 'GEMA01', 5),
#  ('880322-3951', 'MAM032', 5),
#  ('880322-3951', 'MAMN10', 3),
#  ('880322-3951', 'MMKF15', 5),
#  ('880322-3951', 'TNX097', 5)]

# %% [markdown]
# If you inadvertently change the contents of the tables, you
# can always recreate the them with the following command (it
# must be run at the command line):
#
# ```sh
# sqlite3 lab1.sqlite < create-lab1-data.sql
# ```
#
#
# After some of the questions there is a number in brackets.
# This is the number of rows generated by the question. For
# instance, [72] after question a) means that there are 72
# students in the database, you can use that number as an
# indicatation of if your answer is in the right ballpark.
#
# a) What are the names (first name, last name) of all the
#    students? [72]
#
# %%sql

# %%
# %%sql
# SELECT   first_name, last_name
# FROM     students
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Anna', 'Johansson'),
#  ('Anna', 'Johansson'),
#  ('Eva', 'Alm'),
#  ('Eva', 'Nilsson'),
#  ('Elaine', 'Robertson'),
#  ('Maria', 'Nordman'),
#  ('Helena', 'Troberg'),
#  ('Lotta', 'Emanuelsson'),
#  ('Anna', 'Nyström'),
#  ('Maria', 'Andersson'),
#  ('Marie', 'Persson'),
#  ('Märit', 'Aspegren'),
#  ('Ylva', 'Jacobsson'),
#  ('Frida', 'Weidel'),
#  ('Caroline', 'Olsson'),
#  ('Karolin', 'Ek'),
#  ('Eva', 'Hjort'),
#  ('Sofia', 'Kjellberg'),
#  ('Tina', 'Lööf'),
#  ('Lisa', 'Berg'),
#  ('Lotta', 'Bergman'),
#  ('Susanne', 'Dahl'),
#  ('Birgit', 'Ewesson'),
#  ('Ulrika', 'Jonsson'),
#  ('Jenny', 'Lundin'),
#  ('Karin', 'Östberg'),
#  ('Bo', 'Ek'),
#  ('Bo', 'Ek'),
#  ('Bo', 'Ek'),
#  ('Erik', 'Andersson'),
#  ('Erik', 'Andersson'),
#  ('Filip', 'Gustavsson'),
#  ('Niklas', 'Andersson'),
#  ('David', 'Carlsson'),
#  ('Tobias', 'Enberg'),
#  ('Johan', 'Lind'),
#  ('Magnus', 'Pettersson'),
#  ('Filip', 'Persson'),
#  ('Ola', 'Nilsson'),
#  ('Jakob', 'Malmberg'),
#  ('Henrik', 'Berg'),
#  ('John', 'Lind'),
#  ('Patrik', 'Lundh'),
#  ('Mikael', 'Nilsson'),
#  ('Joakim', 'Nilsson'),
#  ('Conny', 'Modig'),
#  ('Christian', 'Wallman'),
#  ('Magnus', 'Strömgren'),
#  ('Daniel', 'Ahlman'),
#  ('Lars', 'Molin'),
#  ('Magnus', 'Nilsson'),
#  ('Anders', 'Olsson'),
#  ('Martin', 'Alm'),
#  ('Håkan', 'Mossgren'),
#  ('Fredrik', 'Ryd'),
#  ('Mats', 'Wikström'),
#  ('Anders', 'Magnusson'),
#  ('Andreas', 'Molin'),
#  ('Johan', 'Brattberg'),
#  ('Johan', 'Olsson'),
#  ('Jonathan', 'Jönsson'),
#  ('Magnus', 'Hultgren'),
#  ('Axel', 'Nord'),
#  ('Henrik', 'Hult'),
#  ('Joakim', 'Hall'),
#  ('Henrik', 'Gustavsson'),
#  ('Torbjörn', 'Modig'),
#  ('Daniel', 'Axelsson'),
#  ('Per-Erik', 'Pettersson'),
#  ('Roger', 'Brorsson'),
#  ('Patrik', 'Ohlsson'),
#  ('Peter', 'Solberg')]

# %% [markdown]
# b) Same as question a) but produce a sorted listing. Sort
#    first by last name and then by first name.

# %%
# %%sql
# SELECT    first_name, last_name
# FROM      students
# ORDER BY  first_name
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Anders', 'Olsson'),
#  ('Anders', 'Magnusson'),
#  ('Andreas', 'Molin'),
#  ('Anna', 'Johansson'),
#  ('Anna', 'Johansson'),
#  ('Anna', 'Nyström'),
#  ('Axel', 'Nord'),
#  ('Birgit', 'Ewesson'),
#  ('Bo', 'Ek'),
#  ('Bo', 'Ek'),
#  ('Bo', 'Ek'),
#  ('Caroline', 'Olsson'),
#  ('Christian', 'Wallman'),
#  ('Conny', 'Modig'),
#  ('Daniel', 'Ahlman'),
#  ('Daniel', 'Axelsson'),
#  ('David', 'Carlsson'),
#  ('Elaine', 'Robertson'),
#  ('Erik', 'Andersson'),
#  ('Erik', 'Andersson'),
#  ('Eva', 'Alm'),
#  ('Eva', 'Nilsson'),
#  ('Eva', 'Hjort'),
#  ('Filip', 'Gustavsson'),
#  ('Filip', 'Persson'),
#  ('Fredrik', 'Ryd'),
#  ('Frida', 'Weidel'),
#  ('Helena', 'Troberg'),
#  ('Henrik', 'Berg'),
#  ('Henrik', 'Hult'),
#  ('Henrik', 'Gustavsson'),
#  ('Håkan', 'Mossgren'),
#  ('Jakob', 'Malmberg'),
#  ('Jenny', 'Lundin'),
#  ('Joakim', 'Nilsson'),
#  ('Joakim', 'Hall'),
#  ('Johan', 'Lind'),
#  ('Johan', 'Brattberg'),
#  ('Johan', 'Olsson'),
#  ('John', 'Lind'),
#  ('Jonathan', 'Jönsson'),
#  ('Karin', 'Östberg'),
#  ('Karolin', 'Ek'),
#  ('Lars', 'Molin'),
#  ('Lisa', 'Berg'),
#  ('Lotta', 'Emanuelsson'),
#  ('Lotta', 'Bergman'),
#  ('Magnus', 'Pettersson'),
#  ('Magnus', 'Strömgren'),
#  ('Magnus', 'Nilsson'),
#  ('Magnus', 'Hultgren'),
#  ('Maria', 'Nordman'),
#  ('Maria', 'Andersson'),
#  ('Marie', 'Persson'),
#  ('Martin', 'Alm'),
#  ('Mats', 'Wikström'),
#  ('Mikael', 'Nilsson'),
#  ('Märit', 'Aspegren'),
#  ('Niklas', 'Andersson'),
#  ('Ola', 'Nilsson'),
#  ('Patrik', 'Lundh'),
#  ('Patrik', 'Ohlsson'),
#  ('Per-Erik', 'Pettersson'),
#  ('Peter', 'Solberg'),
#  ('Roger', 'Brorsson'),
#  ('Sofia', 'Kjellberg'),
#  ('Susanne', 'Dahl'),
#  ('Tina', 'Lööf'),
#  ('Tobias', 'Enberg'),
#  ('Torbjörn', 'Modig'),
#  ('Ulrika', 'Jonsson'),
#  ('Ylva', 'Jacobsson')]

# %% [markdown]
# c) What are the names of the students who were born in 1985?
#    [4]

# %%
# %%sql
# SELECT    first_name, last_name, ssn
# FROM      students
#           WHERE ssn LIKE '85%' --'string%' betyder att % är wildcard
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Ulrika', 'Jonsson', '850706-2762'),
#  ('Bo', 'Ek', '850819-2139'),
#  ('Filip', 'Persson', '850517-2597'),
#  ('Henrik', 'Berg', '850208-1213')]

# %% [markdown]
# d) The next-to-last digit in the social security number is
#    even for females, and odd for males. List the first names
#    of all female students in our database alphabetically
#    (each name should occur only once). Hint: the `substr`
#    function can be useful. [26]

# %%
# %%sql
# SELECT DISTINCT    first_name   -- DISTINCT innebär att vi bara har ett first_name. Även fast det är olika personer
# FROM      students
#           WHERE substr(ssn,10,1)%2 = 0 -- börjar på index 1....
# ORDER BY first_name
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('Anna',),
#  ('Birgit',),
#  ('Caroline',),
#  ('Elaine',),
#  ('Eva',),
#  ('Frida',),
#  ('Helena',),
#  ('Jenny',),
#  ('Karin',),
#  ('Karolin',),
#  ('Lisa',),
#  ('Lotta',),
#  ('Maria',),
#  ('Marie',),
#  ('Märit',),
#  ('Sofia',),
#  ('Susanne',),
#  ('Tina',),
#  ('Ulrika',),
#  ('Ylva',)]

# %% [markdown]
# e) How many students are registered in the database?

# %%
# %%sql
# SELECT COUNT(ssn)
# FROM   students
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [(72,)]

# %% [markdown]
# f) Which courses are offered by the department of
#    Mathematics (their course codes have the form `FMAxxx`)?
#    [22]

# %%
# %%sql
# SELECT *
# FROM   courses
#        WHERE course_code LIKE 'FMA%'
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('FMA021', 'Kontinuerliga system', 'A', 7.5),
#  ('FMA051', 'Optimering', 'A', 6.0),
#  ('FMA091', 'Diskret matematik', 'G1', 6.0),
#  ('FMA111', 'Matematiska strukturer', 'A', 6.0),
#  ('FMA120', 'Matristeori', 'A', 6.0),
#  ('FMA125', 'Matristeori, projektdel', 'A', 3.0),
#  ('FMA135', 'Geometri', 'G1', 6.0),
#  ('FMA140', 'Olinjära dynamiska system', 'A', 6.0),
#  ('FMA145', 'Olinjära dynamiska system, projektdel', 'A', 3.0),
#  ('FMA170', 'Bildanalys', 'A', 6.0),
#  ('FMA175', 'Bildanalys, projektdel', 'A', 3.0),
#  ('FMA200', 'Variationskalkyl', 'A', 6.0),
#  ('FMA240', 'Linjär och kombinatorisk optimering', 'G2', 6.0),
#  ('FMA270', 'Datorseende', 'A', 6.0),
#  ('FMA272', 'Datorseende, projektdel', 'A', 3.0),
#  ('FMA420', 'Linjär algebra', 'G1', 6.0),
#  ('FMA430', 'Flerdimensionell analys', 'G1', 6.0),
#  ('FMAA01', 'Endimensionell analys', 'G1', 15.0),
#  ('FMAF01', 'Matematik - Funktionsteori', 'G2', 7.0),
#  ('FMAF05', 'Matematik - System och transformer', 'G2', 7.0),
#  ('FMAF10', 'Tillämpad matematik - Linjära system', 'G2', 5.0),
#  ('FMAN10', 'Algebraiska strukturer', 'A', 7.5)]

# %% [markdown]
# g) Which courses give more than 7.5 credits? [16]

# %%
# %%sql
# SELECT course_code, course_name, credits
# FROM   courses
#        WHERE credits >= 7.5
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [('EDA016', 'Programmeringsteknik', 7.5),
#  ('EDA031', 'C++ - programmering', 7.5),
#  ('EDA095', 'Nätverksprogrammering', 7.5),
#  ('EDA132', 'Tillämpad artificiell intelligens', 7.5),
#  ('EDA180', 'Kompilatorteknik', 7.5),
#  ('EDAF75', 'Databasteknik', 7.5),
#  ('EDA221', 'Datorgrafik', 7.5),
#  ('EDA230', 'Optimerande kompilatorer', 7.5),
#  ('EDA270', 'Coachning av programvaruteam', 9.0),
#  ('EDA385', 'Konstruktion av inbyggda system, fördjupningskurs', 7.5),
#  ('EDAA01', 'Programmeringsteknik - fördjupningskurs', 7.5),
#  ('EDAA05', 'Datorer i system', 8.0),
#  ('EDAF10', 'Objektorienterad modellering och diskreta strukturer', 7.5),
#  ('EDAN01', 'Constraint-programmering', 7.5),
#  ('EDAN10', 'Konfigurationshantering', 7.5),
#  ('EDAN15', 'Konstruktion av inbyggda system', 7.5),
#  ('EDAN20', 'Språkteknologi', 7.5),
#  ('EDAN30', 'Fotorealistisk datorgrafik', 7.5),
#  ('EDAN35', 'Högpresterande datorgrafik', 7.5),
#  ('EDAN40', 'Funktionsprogrammering', 7.5),
#  ('EDAN50', 'Intelligenta system - projekt', 7.5),
#  ('EDAN55', 'Avancerade algoritmer', 7.5),
#  ('EDAN60', 'Språkteknologi: Projekt', 7.5),
#  ('EDI042', 'Kodningsteknik', 7.5),
#  ('EDIN01', 'Kryptoteknik', 7.5),
#  ('EDIN05', 'Matematisk kryptologi', 7.5),
#  ('EEM031', 'Sensorteknik', 7.5),
#  ('EEMF05', 'Medicinsk mätteknik', 7.5),
#  ('EEMN01', 'Mikrosensorer', 7.5),
#  ('EEMN05', 'EMC, störningar och störningsbegränsning', 7.5),
#  ('EEMN10', 'Datorbaserade mätsystem', 7.5),
#  ('EEMN15', 'Ultraljudsfysik och teknik', 7.5),
#  ('EIE061', 'Projekt i industriell elektroteknik och automation', 7.5),
#  ('EIEF01', 'Tillämpad mekatronik', 10.0),
#  ('EIEN01', 'Mekatronik, industriell produktframtagning', 10.0),
#  ('EIT020', 'Digitalteknik', 9.0),
#  ('EIT060', 'Datasäkerhet', 7.5),
#  ('EIT140', 'OFDM för bredbandskommunikation', 7.5),
#  ('EITF01', 'Digitala bilder – kompression', 9.0),
#  ('EITF20', 'Datorarkitektur', 7.5),
#  ('EITF35', 'Digitala strukturer på kisel', 7.5),
#  ('EITF40', 'Digitala och analoga projekt', 7.5),
#  ('EITN10', 'Multipelantennsystem', 7.5),
#  ('EITN30', 'Internet inuti', 7.5),
#  ('EITN35', 'Projekt i elektro- och informationsteknik', 7.5),
#  ('EITN45', 'Informationsteori', 7.5),
#  ('EITN50', 'Avancerad datasäkerhet', 7.5),
#  ('ESS050', 'Elektromagnetisk fältteori', 9.0),
#  ('ETI265', 'Signalbehandling i multimedia', 7.5),
#  ('ETIA01', 'Elektronik', 8.0),
#  ('ETIA10', 'Patent och annan immaterialrätt', 7.5),
#  ('ETIF05', 'Grundläggande radioteknik', 7.5),
#  ('ETIF10', 'Signalbehandling - design och implementering', 7.5),
#  ('ETIF15', 'Medicinsk signalbehandling', 7.5),
#  ('ETIN10', 'Kanalmodellering för trådlös kommunikation', 7.5),
#  ('ETIN15', 'Radiosystem', 7.5),
#  ('ETIN20', 'Digital IC-konstruktion', 7.5),
#  ('ETIN35', 'IC-projekt 1', 7.5),
#  ('ETIN40', 'IC-projekt 2', 7.5),
#  ('ETIN45', 'DSP-design', 7.5),
#  ('ETIN55', 'Integrerade A/D och D/A omvandlare', 7.5),
#  ('ETIN60', 'Avancerade A/D och D/A omvandlare', 7.5),
#  ('ETIN70', 'Modern elektronik', 7.5),
#  ('ETIN80', 'Algoritmer i signalprocessorer - projektkurs', 7.5),
#  ('ETS061', 'Simulering', 7.5),
#  ('ETS170', 'Kravhantering', 7.5),
#  ('ETS200', 'Programvarutestning', 7.5),
#  ('ETSF10', 'Internetprotokoll', 7.5),
#  ('ETSN01', 'Avancerad telekommunikation', 7.5),
#  ('ETSN05', 'Programvaruutveckling för stora system', 7.5),
#  ('ETT051', 'Digital kommunikation', 7.5),
#  ('ETTN01', 'Digital kommunikation, fortsättningskurs', 7.5),
#  ('ETTN05', 'Adaptiv signalbehandling', 7.5),
#  ('ETTN10', 'Optimal signalbehandling', 7.5),
#  ('ETTN15', 'Moderna trådlösa system - LTE och dess efterföljare', 7.5),
#  ('EXTA35', 'Introduktionskurs i kinesiska för civilingenjörer', 15.0),
#  ('EXTF60', 'Introduktionskurs i kinesiska för civilingenjörer, del 2', 15.0),
#  ('FAF150', 'Medicinsk optik', 7.5),
#  ('FAFF20', 'Multispektral avbildning', 7.5),
#  ('FAFF25', 'Fysik', 11.0),
#  ('FMA021', 'Kontinuerliga system', 7.5),
#  ('FMAA01', 'Endimensionell analys', 15.0),
#  ('FMAN10', 'Algebraiska strukturer', 7.5),
#  ('FMI040', 'Energisystemanalys: Förnybara energikällor', 7.5),
#  ('FMI050', 'Energisystemanalys: energi, miljö och naturresurser', 7.5),
#  ('FMIF15', 'Teknisk miljövetenskap', 7.5),
#  ('FMNN05', 'Simuleringsverktyg', 7.5),
#  ('FMNN25', 'Avancerad kurs i numeriska algoritmer med Python/SciPy', 7.5),
#  ('FMS012', 'Matematisk statistik, allmän kurs', 9.0),
#  ('FMS051', 'Matematisk statistik, tidsserieanalys', 7.5),
#  ('FMS072', 'Försöksplanering', 7.5),
#  ('FMS091', 'Monte Carlo-baserade statistiska metoder', 7.5),
#  ('FMS110', 'Olinjära tidsserier', 7.5),
#  ('FMS155', 'Statistisk modellering av extremvärden', 7.5),
#  ('FMSF10', 'Stationära stokastiska processer', 7.5),
#  ('FMSF15', 'Markovprocesser', 7.5),
#  ('FMSN20', 'Spatial statistik med bildanalys', 7.5),
#  ('FMSN30', 'Linjär och logistisk regression', 7.5),
#  ('FMSN35', 'Stationär och icke-stationär spektralanalys', 7.5),
#  ('FRT010', 'Reglerteknik, allmän kurs', 7.5),
#  ('FRT041', 'Systemidentifiering', 7.5),
#  ('FRT090', 'Projekt i reglerteknik', 7.5),
#  ('FRTN01', 'Realtidssystem', 10.0),
#  ('FRTN05', 'Olinjär reglering och servosystem', 7.5),
#  ('FRTN10', 'Flervariabel reglering', 7.5),
#  ('FRTN15', 'Prediktiv reglering', 7.5),
#  ('GEMA01', 'Franska för tekniker: språk, kultur och samhällsliv, grundkurs', 7.5),
#  ('GEMA20', 'Engelska för tekniker', 7.5),
#  ('GEMA25', 'Tyska för tekniker', 7.5),
#  ('GEMA40', 'Entreprenörskap och affärsutveckling', 7.5),
#  ('GEMA60', 'Juridik för tekniker', 7.5),
#  ('GEMA65', 'Kinesiska för tekniker', 7.5),
#  ('GEMA70', 'Japanska för tekniker', 15.0),
#  ('KII010', 'Industriellt miljöarbete', 7.5),
#  ('MAM032', 'Arbete-människa-teknik, projekt', 7.5),
#  ('MAM101', 'Virtual Reality i teori och praktik', 7.5),
#  ('MAM120', 'Användbarhetsutvärdering', 7.5),
#  ('MAMN01', 'Avancerad interaktionsdesign', 7.5),
#  ('MAMN10', 'Interaktion 1: Neuromodellering, kognitiv robotik och agenter', 7.5),
#  ('MAMN15', 'Interaktion 2: Virtualitet och kognitiv modellering', 7.5),
#  ('MAMN25', 'Interaktionsdesign', 7.5),
#  ('MIE080', 'Automation', 7.5),
#  ('MIE090', 'Automation för komplexa system', 7.5),
#  ('MIOA01', 'Industriell ekonomi, allmän kurs', 9.0),
#  ('MMKF15', 'Tillämpad robotteknik', 7.5),
#  ('TEK280', 'Teknikstödd kommunikation', 7.5),
#  ('TNX097', 'Rehabiliteringsteknik', 7.5),
#  ('TNX153', 'Rehabiliteringsteknik och design', 7.5)]

# %% [markdown]
# h) How may courses are there for each level (`G1`, `G2`, and
#    `A`)?

# %%
# %%sql
# SELECT count(*), level
# FROM   courses
# GROUP BY level
# Out:
#  * sqlite:///lab1.sqlite
# Done.
# [(31, 'G1'), (60, 'G2'), (87, 'A')]

# %% [markdown]
# In the next few problems, we'll look at the results of the
# student with the social security number 910101–1234 -- to
# make things a lot easier, you can create a `VIEW` with all
# his results (see lecture 3).

# %%
# %%sql
# DROP VIEW IF EXISTS ...;
# CREATE VIEW ... AS

# %% [markdown]
# i) Which courses (course codes only) have been taken by the
#    student with the social security number 910101–1234? [35]

# %%
# %%sql

# %% [markdown]
# j) What are the names of these courses, and how many credits
#    do they give?

# %%
# %%sql

# %% [markdown]
# k) How many credits has the student taken?

# %%
# %%sql

# %% [markdown]
# l) Which is the student’s grade average?

# %%
# %%sql

# %% [markdown]
# m) Which students have taken 0 credits? [11] This problem
#    can be solved in several ways, first do it with an outer
#    join:

# %%
# %%sql

# %% [markdown]
# Now do the same thing using a subquery:

# %%
# %%sql

# %% [markdown]
# n) List the names and average grades of the 10 students with
#    the highest grade average?

# %%
# %%sql

# %% [markdown]
# o) List the social security number and total number of
#    credits for all students. Students with no credits should
#    be included in the listing, with 0 credits (not `NULL`).
#
#    If you do this with an outer join (and I recommend you
#    try it!) you might want to use the function
#    `coalesce(v1, v2, ...)`; it returns the first value which
#    is not `NULL`, so `coalesce(avg(grade), 0)` would give 0
#    if the were no grades (i.e., if `grade` were `NULL`), you
#    can also try the `ifnull` function.
#
#    (It may be a little bit tricky to get this query right,
#    if you're missing the students with 0 credits, don't
#    worry, your TA will help you get it right). [72]

# %%
# %%sql

# %% [markdown]
# p) Is there more than one student with the same name? If so,
#    who are these students and what are their social security
#    numbers? [7]
#
#    As usual there are several ways of solving this, try to
#    solve it using a `WITH`-statement where you create a
#    table with all duplicate names, and then use it in a
#    `JOIN`:

# %%
# %%sql

# %% [markdown]
# q) What 5 courses have the highest grade average?

# %%
# %%sql

# %% [markdown]
# r) (Not required) What are the 'best' initial letters of the
#    last names, i.e., if you take the average grades for each
#    first letter of the last name, which three initials have
#    the highest averages? That is, we want a table like (but
#    probably with other values):
#
# <center>
# <table rules="all">
#   <tr>
#    <th>initial</th>
#    <th>gpa</th>
#   </tr>
#   <tr>
#    <td>A</td>
#    <td>4.2</td>
#   </tr>
#   <tr>
#    <td>L</td>
#    <td>4.18</td>
#   </tr>
#   <tr>
#    <td>E</td>
#    <td>4.0</td>
#   </tr>
# </table>
# </center>

# %%
# %%sql
